# %% [markdown]
# 1.Loading the lendingclub data

# %%
# Immports 
import os
import pandas as pd

# %%
lending=pd.read_csv('LendingClub.csv')
lending.head()
# Out:
#                  emp_title  emp_length state homeownership  annual_income  \
# 0  global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1   warehouse office clerk        10.0    HI          RENT        40000.0
# 2                 assembly         3.0    WI          RENT        40000.0
# 3         customer service         1.0    PA          RENT        30000.0
# 4     security supervisor         10.0    CA          RENT        35000.0
#
#    verified_income  debt_to_income  annual_income_joint  \
# 0         Verified           18.01                  NaN
# 1     Not Verified            5.04                  NaN
# 2  Source Verified           21.15                  NaN
# 3     Not Verified           10.16                  NaN
# 4         Verified           57.96              57000.0
#
#   verification_income_joint  debt_to_income_joint  ...  sub_grade  \
# 0                       NaN                   NaN  ...         C3
# ...

# %%
lending.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 55 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   emp_title                         9167 non-null   object
#  1   emp_length                        9183 non-null   float64
#  2   state                             10000 non-null  object
#  3   homeownership                     10000 non-null  object
#  4   annual_income                     10000 non-null  float64
#  5   verified_income                   10000 non-null  object
#  6   debt_to_income                    9976 non-null   float64
#  7   annual_income_joint               1495 non-null   float64
#  8   verification_income_joint         1455 non-null   object
#  9   debt_to_income_joint              1495 non-null   float64
#  10  delinq_2y                         10000 non-null  int64
# ...

# %%
lending.head()
# Out:
#                  emp_title  emp_length state homeownership  annual_income  \
# 0  global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1   warehouse office clerk        10.0    HI          RENT        40000.0
# 2                 assembly         3.0    WI          RENT        40000.0
# 3         customer service         1.0    PA          RENT        30000.0
# 4     security supervisor         10.0    CA          RENT        35000.0
#
#    verified_income  debt_to_income  annual_income_joint  \
# 0         Verified           18.01                  NaN
# 1     Not Verified            5.04                  NaN
# 2  Source Verified           21.15                  NaN
# 3     Not Verified           10.16                  NaN
# 4         Verified           57.96              57000.0
#
#   verification_income_joint  debt_to_income_joint  ...  sub_grade  \
# 0                       NaN                   NaN  ...         C3
# ...

# %% [markdown]
# 2.Exploring the data

# %%
import pandas as pd
missing =pd.concat([lending.isnull().sum(),100*lending.isnull().mean()], axis=1)
missing.columns= ['count', '%']
missing.sort_values(by='count')
# Out:
#                                   count      %
# paid_late_fees                        0   0.00
# issue_month                           0   0.00
# num_satisfactory_accounts             0   0.00
# paid_interest                         0   0.00
# num_accounts_30d_past_due             0   0.00
# num_active_debit_accounts             0   0.00
# total_debit_limit                     0   0.00
# num_total_cc_accounts                 0   0.00
# num_open_cc_accounts                  0   0.00
# num_cc_carrying_balance               0   0.00
# num_mort_accounts                     0   0.00
# account_never_delinq_percent          0   0.00
# tax_liens                             0   0.00
# public_record_bankrupt                0   0.00
# loan_purpose                          0   0.00
# application_type                      0   0.00
# loan_amount                           0   0.00
# term                                  0   0.00
# interest_rate                         0   0.00
# ...

# %% [markdown]
# Counting the na values and the perentages associated with them in descending order. So, we can see that the verification_income_joint has the highest percentage of missing values

# %%
# Selecting columns that  have dtypes 'object'
lending.select_dtypes('object')
# Out:
#                     emp_title state homeownership  verified_income  \
# 0     global config engineer     NJ      MORTGAGE         Verified
# 1      warehouse office clerk    HI          RENT     Not Verified
# 2                    assembly    WI          RENT  Source Verified
# 3            customer service    PA          RENT     Not Verified
# 4        security supervisor     CA          RENT         Verified
# ...                       ...   ...           ...              ...
# 9995                   owner     TX          RENT  Source Verified
# 9996                 director    PA      MORTGAGE         Verified
# 9997                toolmaker    CT      MORTGAGE         Verified
# 9998                  manager    WI      MORTGAGE  Source Verified
# 9999       operations analyst    CT          RENT     Not Verified
#
#      verification_income_joint        loan_purpose application_type grade  \
# 0                          NaN              moving       individual     C
# ...

# %%
lending.describe()
# Out:
#         emp_length  annual_income  debt_to_income  annual_income_joint  \
# count  9183.000000   1.000000e+04     9976.000000         1.495000e+03
# mean      5.930306   7.922215e+04       19.308192         1.279146e+05
# std       3.703734   6.473429e+04       15.004851         7.016838e+04
# min       0.000000   0.000000e+00        0.000000         1.920000e+04
# 25%       2.000000   4.500000e+04       11.057500         8.683350e+04
# 50%       6.000000   6.500000e+04       17.570000         1.130000e+05
# 75%      10.000000   9.500000e+04       25.002500         1.515455e+05
# max      10.000000   2.300000e+06      469.090000         1.100000e+06
#
#        debt_to_income_joint    delinq_2y  months_since_last_delinq  \
# count           1495.000000  10000.00000               4342.000000
# mean              19.979304      0.21600                 36.760709
# std                8.054781      0.68366                 21.634939
# ...

# %%
lending[lending['emp_title'].notna()]
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...

# %%
lending['emp_title'].value_counts()
# Out:
# manager                     218
# owner                       204
# teacher                     201
# driver                      123
# sales                        97
#                            ...
# drilling fluids engineer      1
# rep                           1
# civil engineer 2              1
# lead maintenance tech         1
# account supervisor            1
# Name: emp_title, Length: 4741, dtype: int64

# %%
df['emp_title'].value_counts()
# Out:
# manager                     218
# owner                       204
# teacher                     201
# driver                      123
# sales                        97
#                            ...
# drilling fluids engineer      1
# rep                           1
# civil engineer 2              1
# lead maintenance tech         1
# account supervisor            1
# Name: emp_title, Length: 4741, dtype: int64

# %%
lending['emp_length'].unique()
# Out:
# array([ 3., 10.,  1., nan,  2.,  5.,  7.,  4.,  9.,  0.,  6.,  8.])

# %%
lending['verification_income_joint'].isna()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 9995     True
# 9996     True
# 9997    False
# 9998     True
# 9999     True
# Name: verification_income_joint, Length: 10000, dtype: bool

# %%
lending
# Out:
#                     emp_title  emp_length state homeownership  annual_income  \
# 0     global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1      warehouse office clerk        10.0    HI          RENT        40000.0
# 2                    assembly         3.0    WI          RENT        40000.0
# 3            customer service         1.0    PA          RENT        30000.0
# 4        security supervisor         10.0    CA          RENT        35000.0
# ...                       ...         ...   ...           ...            ...
# 9995                   owner         10.0    TX          RENT       108000.0
# 9996                 director         8.0    PA      MORTGAGE       121000.0
# 9997                toolmaker        10.0    CT      MORTGAGE        67000.0
# 9998                  manager         1.0    WI      MORTGAGE        80000.0
# 9999       operations analyst         3.0    CT          RENT        66000.0
#
# ...
